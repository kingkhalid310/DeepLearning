# %% [markdown]
# Assignment 4\
# Khalid Saifullah\
# ID: A20423546\
# \
# Solution to question 2(d)

# %%
# Loading all the libraries
import pickle
import numpy as np
import random
import keras

from keras import optimizers
import matplotlib.pyplot as plt
from keras.optimizers import SGD
from keras import Input, layers, Model
from keras.utils import to_categorical
from keras.models import Sequential, load_model
from sklearn.model_selection import train_test_split
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, BatchNormalization, Activation, Dropout

random.seed(0)

# %%
# This Unpickle function has been obtained from Cifar-10 website
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict

# Preparing the training and testing dataset
def prepare_data():
    # Loading the training dataset
    batch_labels = []
    batch_images = []
    for n in range(1, 6):
        batch_dict = unpickle(f"cifar-10-batches-py/data_batch_{n}")
        # Addding the labels to the list of batch labels
        batch_labels.append(batch_dict[b'labels'])
        # Loading the images, and resizing them to 10000x3x32x32
        data = batch_dict[b'data'].reshape((10000,3,32,32))
        # Modifying the axis to make it 10000x32x32x3
        data = np.moveaxis(data, 1, -1)
        batch_images.append(data)
    train_labels = np.concatenate(batch_labels, axis=0)
    train_images = np.concatenate(batch_images, axis=0)
    # Loading the testing dataset
    test_dict = unpickle(f"cifar-10-batches-py/test_batch")
    test_labels = np.array(test_dict[b'labels'])
    test_images = test_dict[b'data'].reshape((10000,3,32,32))
    test_images = np.moveaxis(test_images, 1, -1)
    # Normalizing the images
    train_images = train_images.astype('float32') / 255.0
    test_images = test_images.astype('float32') / 255.0
    # 1-hot encoding the labels
    train_labels = to_categorical(train_labels)
    test_labels = to_categorical(test_labels)
    return train_images, train_labels, test_images, test_labels

# defining the CNN model
def define_model():
    
    input_tensor = Input(shape=(32,32,3))
    a1 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(input_tensor)
    a1 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(a1)
    amax = MaxPooling2D((2, 2))(a1)

    b1 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(amax)
    b1 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same')(b1)
    bmax = MaxPooling2D((2, 2))(b1)

    # inception block 1
    branch_a = layers.Conv2D(64, (1,1), activation='relu', padding='same', strides=2)(bmax)
    branch_b = layers.Conv2D(64, (1,1), activation='relu', padding='same')(bmax)
    branch_b = layers.Conv2D(64, (3,3), activation='relu', padding='same', strides=2)(branch_b)
    branch_d = layers.Conv2D(64, (1,1), activation='relu', padding='same')(bmax)
    branch_d = layers.Conv2D(64, (3,3), activation='relu', padding='same')(branch_d)
    branch_d = layers.Conv2D(64, (3,3), activation='relu', padding='same', strides=2)(branch_d)
    output_tensor1 = layers.concatenate([branch_a, branch_b, branch_d], axis=3)
    
    # inception block 2
    branch_a = layers.Conv2D(64, (1,1), activation='relu', padding='same')(output_tensor1)
    branch_a = layers.Conv2D(64, (3,3), activation='relu', padding='same')(branch_a)
    branch_b = layers.Conv2D(64, (1,1), activation='relu', padding='same')(output_tensor1)
    branch_b = layers.Conv2D(64, (5,5), activation='relu', padding='same')(branch_d)
    branch_c = MaxPooling2D((3,3), strides=(1,1), padding='same')(output_tensor1)
    branch_c = Conv2D(64, (1,1), padding='same', activation='relu')(branch_c)
    output_tensor2 = layers.concatenate([branch_a, branch_b, branch_c], axis=3)

    flat= Flatten()(output_tensor2)
    flat = Dense(128, activation='relu', kernel_initializer='he_uniform')(flat)
    output_tensor = Dense(10, activation='softmax')(flat)
    model = Model(inputs = input_tensor, outputs = output_tensor)
    model.summary()
    
    # compiling the model
    opt = SGD(lr=0.001, momentum=0.9)
    model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# plotting the learning curves
def learning_curves(history):
   # plotting loss
    print(history.history.keys())
    epochs = range(1, len(history.history['accuracy'])+1)
    plt.figure(figsize=(10,12), facecolor='w')
    plt.subplot(211)
    plt.title('Cross Entropy Loss')
    plt.plot(epochs, history.history['loss'], 'bo', label='Training loss')
    plt.plot(epochs, history.history['val_loss'], 'r', label='Validation loss')
    plt.legend()
    # plotting accuracy
    plt.subplot(212)
    plt.title('Classification Accuracy')
    plt.plot(epochs, history.history['accuracy'], 'bo', label='Training accuracy')
    plt.plot(epochs, history.history['val_accuracy'], 'r', label='Validation accuracy')
    plt.legend()
    plt.show()
    plt.close()

# defining the run_model
def run_model():
    # defining the model
    model = define_model()
    # loading the prepared dataset
    trainX, trainY, testX, testY = prepare_data()
    # Splitting into training and validation dataset
    trainX, valX, trainY, valY = train_test_split(trainX, trainY, test_size=0.3, shuffle=True, random_state=0, stratify=trainY)
    # fitting the model
    history = model.fit(trainX, trainY, epochs=40, batch_size=64, validation_data=(testX, testY))
    # Showing the learning curves
    learning_curves(history)
    # saving the model
    model.save('cifar10_inceptionblock.h5')

# %%
# Running the run_model
run_model()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 32)   896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)     0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 64)     36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 4, 4, 64)     4160        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 4, 4, 64)     36928       conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 64)     36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 4, 192)    0           conv2d_4[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 4, 64)     12352       concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 192)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 64)     36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 64)     102464      conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 4, 4, 64)     12352       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 192)    0           conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 3072)         0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          393344      flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           1290        dense[0][0]
# ==================================================================================================
# Total params: 747,562
# Trainable params: 747,562
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/40
# 547/547 [==============================] - 112s 202ms/step - loss: 2.1368 - accuracy: 0.2135 - val_loss: 1.7407 - val_accuracy: 0.3694
# Epoch 2/40
# 547/547 [==============================] - 109s 200ms/step - loss: 1.6413 - accuracy: 0.4065 - val_loss: 1.4697 - val_accuracy: 0.4713
# Epoch 3/40
# 547/547 [==============================] - 109s 199ms/step - loss: 1.4659 - accuracy: 0.4720 - val_loss: 1.4127 - val_accuracy: 0.4841
# Epoch 4/40
# 547/547 [==============================] - 107s 196ms/step - loss: 1.3670 - accuracy: 0.5085 - val_loss: 1.3437 - val_accuracy: 0.5135
# Epoch 5/40
# 547/547 [==============================] - 105s 193ms/step - loss: 1.2806 - accuracy: 0.5431 - val_loss: 1.2045 - val_accuracy: 0.5664
# Epoch 6/40
# 547/547 [==============================] - 106s 195ms/step - loss: 1.1971 - accuracy: 0.5762 - val_loss: 1.1888 - val_accuracy: 0.5725
# Epoch 7/40
# 547/547 [==============================] - 109s 199ms/step - loss: 1.1156 - accuracy: 0.6038 - val_loss: 1.1484 - val_accuracy: 0.5933
# Epoch 8/40
# 547/547 [==============================] - 108s 197ms/step - loss: 1.0712 - accuracy: 0.6231 - val_loss: 1.1341 - val_accuracy: 0.5916
# Epoch 9/40
# 547/547 [==============================] - 110s 200ms/step - loss: 0.9877 - accuracy: 0.6473 - val_loss: 1.1553 - val_accuracy: 0.5911
# Epoch 10/40
# 547/547 [==============================] - 109s 198ms/step - loss: 0.9469 - accuracy: 0.6663 - val_loss: 1.1051 - val_accuracy: 0.6112
# Epoch 11/40
# 547/547 [==============================] - 109s 199ms/step - loss: 0.8801 - accuracy: 0.6898 - val_loss: 1.0376 - val_accuracy: 0.6405
# Epoch 12/40
# 547/547 [==============================] - 108s 197ms/step - loss: 0.8242 - accuracy: 0.7089 - val_loss: 1.0441 - val_accuracy: 0.6433
# Epoch 13/40
# 547/547 [==============================] - 109s 199ms/step - loss: 0.7876 - accuracy: 0.7239 - val_loss: 1.0227 - val_accuracy: 0.6491
# Epoch 14/40
# 547/547 [==============================] - 107s 196ms/step - loss: 0.7255 - accuracy: 0.7476 - val_loss: 1.0123 - val_accuracy: 0.6594
# Epoch 15/40
# 547/547 [==============================] - 107s 195ms/step - loss: 0.6820 - accuracy: 0.7585 - val_loss: 1.1700 - val_accuracy: 0.6260
# Epoch 16/40
# 547/547 [==============================] - 110s 201ms/step - loss: 0.6480 - accuracy: 0.7724 - val_loss: 1.0053 - val_accuracy: 0.6689
# Epoch 17/40
# 547/547 [==============================] - 110s 201ms/step - loss: 0.5871 - accuracy: 0.7939 - val_loss: 0.9989 - val_accuracy: 0.6711
# Epoch 18/40
# 547/547 [==============================] - 120s 219ms/step - loss: 0.5457 - accuracy: 0.8053 - val_loss: 1.0480 - val_accuracy: 0.6594
# Epoch 19/40
# 547/547 [==============================] - 111s 202ms/step - loss: 0.5142 - accuracy: 0.8202 - val_loss: 1.0289 - val_accuracy: 0.6749
# Epoch 20/40
# 547/547 [==============================] - 110s 201ms/step - loss: 0.4454 - accuracy: 0.8431 - val_loss: 1.0932 - val_accuracy: 0.6697
# Epoch 21/40
# 547/547 [==============================] - 111s 204ms/step - loss: 0.4052 - accuracy: 0.8595 - val_loss: 1.1704 - val_accuracy: 0.6471
# Epoch 22/40
# 547/547 [==============================] - 109s 200ms/step - loss: 0.3674 - accuracy: 0.8721 - val_loss: 1.1410 - val_accuracy: 0.6685
# Epoch 23/40
# 547/547 [==============================] - 111s 203ms/step - loss: 0.3294 - accuracy: 0.8844 - val_loss: 1.2061 - val_accuracy: 0.6643
# Epoch 24/40
# 547/547 [==============================] - 111s 203ms/step - loss: 0.2836 - accuracy: 0.9026 - val_loss: 1.2334 - val_accuracy: 0.6686
# Epoch 25/40
# 547/547 [==============================] - 110s 202ms/step - loss: 0.2543 - accuracy: 0.9121 - val_loss: 1.2627 - val_accuracy: 0.6702
# Epoch 26/40
# 547/547 [==============================] - 111s 203ms/step - loss: 0.2171 - accuracy: 0.9232 - val_loss: 1.4239 - val_accuracy: 0.6664
# Epoch 27/40
# 547/547 [==============================] - 109s 200ms/step - loss: 0.1986 - accuracy: 0.9297 - val_loss: 1.4757 - val_accuracy: 0.6662
# Epoch 28/40
# 547/547 [==============================] - 110s 202ms/step - loss: 0.1820 - accuracy: 0.9377 - val_loss: 1.4827 - val_accuracy: 0.6681
# Epoch 29/40
# 547/547 [==============================] - 108s 197ms/step - loss: 0.1423 - accuracy: 0.9510 - val_loss: 1.6814 - val_accuracy: 0.6535
# Epoch 30/40
# 547/547 [==============================] - 100s 184ms/step - loss: 0.1400 - accuracy: 0.9513 - val_loss: 1.7892 - val_accuracy: 0.6579
# Epoch 31/40
# 547/547 [==============================] - 74s 135ms/step - loss: 0.1258 - accuracy: 0.9562 - val_loss: 1.7785 - val_accuracy: 0.6580
# Epoch 32/40
# 547/547 [==============================] - 75s 137ms/step - loss: 0.1121 - accuracy: 0.9615 - val_loss: 1.7522 - val_accuracy: 0.6590
# Epoch 33/40
# 547/547 [==============================] - 75s 138ms/step - loss: 0.0884 - accuracy: 0.9703 - val_loss: 1.8180 - val_accuracy: 0.6549
# Epoch 34/40
# 547/547 [==============================] - 74s 136ms/step - loss: 0.0941 - accuracy: 0.9687 - val_loss: 2.0400 - val_accuracy: 0.6621
# Epoch 35/40
# 547/547 [==============================] - 73s 133ms/step - loss: 0.0725 - accuracy: 0.9757 - val_loss: 1.9594 - val_accuracy: 0.6680
# Epoch 36/40
# 547/547 [==============================] - 73s 134ms/step - loss: 0.0661 - accuracy: 0.9762 - val_loss: 2.0354 - val_accuracy: 0.6638
# Epoch 37/40
# 547/547 [==============================] - 73s 134ms/step - loss: 0.0611 - accuracy: 0.9793 - val_loss: 2.1722 - val_accuracy: 0.6718
# Epoch 38/40
# 547/547 [==============================] - 73s 134ms/step - loss: 0.0562 - accuracy: 0.9803 - val_loss: 2.0481 - val_accuracy: 0.6586
# Epoch 39/40
# 547/547 [==============================] - 73s 134ms/step - loss: 0.0688 - accuracy: 0.9755 - val_loss: 2.0971 - val_accuracy: 0.6724
# Epoch 40/40
# 547/547 [==============================] - 73s 134ms/step - loss: 0.0598 - accuracy: 0.9788 - val_loss: 2.1040 - val_accuracy: 0.6719
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Evaluating the final model on the testing dataset
trainX, trainY, testX, testY = prepare_data()
final_model = load_model('cifar10_inceptionblock.h5')
_, acc = final_model.evaluate(testX, testY, verbose=0)
print('>> Accuracy = %.3f' % (acc * 100.0))
# Out:
# >> Accuracy = 67.190

# %%
trainX, trainY, testX, testY = prepare_data()
plt.imshow(trainX[50])
trainX[50].shape
# Out:
# (32, 32, 3)
